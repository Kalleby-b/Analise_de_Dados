# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\user\\Downloads\\archive (8)\\total_data.csv")
df_abril2019 = pd.read_csv("C:\\Users\\user\\Downloads\\archive (8)\\abril2019.csv")
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_11008\5234723.py:2: DtypeWarning: Columns (1,17,19,20,28,33,34,54,62,63,66,68,69,88) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("C:\\Users\\user\\Downloads\\archive (8)\\total_data.csv")
# C:\Users\user\AppData\Local\Temp\ipykernel_11008\5234723.py:3: DtypeWarning: Columns (61,62,94) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_abril2019 = pd.read_csv("C:\\Users\\user\\Downloads\\archive (8)\\abril2019.csv")

# %%
df[df["property_type"].isnull()]
# Out:
#         Unnamed: 0        id                            listing_url  \
# 290069     35710.0  32590477  https://www.airbnb.com/rooms/32590477
#
#            scrape_id last_scraped  \
# 290069  2.019031e+13   2019-03-13
#
#                                                    name  \
# 290069  Na quadra da praia. Por aqui, só boas energias!
#
#                                                   summary  \
# 290069  Ap delicioso em rua pequena, sem saída, com vi...
#
#                                                     space  \
# 290069  Além do quarto, os hóspedes podem utilizar a s...
#
#                                               description experiences_offered  \
# 290069  Ap delicioso em rua pequena, sem saída, com vi...                none
#
#         ... minimum_minimum_nights maximum_minimum_nights  \
# 290069  ...                    NaN                    NaN
#
#        minimum_maximum_nights maximum_maximum_nights minimum_nights_avg_ntm  \
# ...

# %%
df_abril2019.loc[df_abril2019["id"] == 32590477]
# Out:
#              id                            listing_url       scrape_id  \
# 34749  32590477  https://www.airbnb.com/rooms/32590477  20190416181629
#
#       last_scraped                                             name  \
# 34749   2019-04-17  Na quadra da praia. Por aqui, só boas energias!
#
#                                                  summary  \
# 34749  Ap delicioso em rua pequena, sem saída, com vi...
#
#                                                    space  \
# 34749  Além do quarto, os hóspedes podem utilizar a s...
#
#                                              description experiences_offered  \
# 34749  Ap delicioso em rua pequena, sem saída, com vi...                none
#
#                                    neighborhood_overview  ...  \
# 34749  Tudo! Metrô, supermercado Zona Sul e Pão de Aç...  ...
#
#       instant_bookable is_business_travel_ready cancellation_policy  \
# 34749                t                        f            moderate
#
# ...

# %%
a = df_abril2019.loc[4749]
a.loc["property_type"]
# Out:
# 'Apartment'

# %%
df["property_type"].fillna("Apartment", inplace= True)

# %%
df["property_type"].isnull().sum()
# Out:
# 0

# %%
grup = df.groupby("id")

# %%
df_n_repete = grup.first()

# %%
nomes = grup.groups.keys()
df_n_repete["id"] = nomes
df_n_repete
# Out:
#                 Unnamed: 0                          listing_url     scrape_id  \
# id
# 17878                  0.0   https://www.airbnb.com/rooms/17878  2.018082e+13
# 21280                  1.0   https://www.airbnb.com/rooms/21280  2.020012e+13
# 24480                  1.0   https://www.airbnb.com/rooms/24480  2.018082e+13
# 25026                  2.0   https://www.airbnb.com/rooms/25026  2.018082e+13
# 31560                  3.0   https://www.airbnb.com/rooms/31560  2.018082e+13
# ...                    ...                                  ...           ...
# 996602              1044.0  https://www.airbnb.com/rooms/996602  2.019042e+13
# 996981              1045.0  https://www.airbnb.com/rooms/996981  2.019042e+13
# 997432              1046.0  https://www.airbnb.com/rooms/997432  2.019042e+13
# 99971                 49.0   https://www.airbnb.com/rooms/99971  2.019042e+13
# within an hour         NaN                                 100%           NaN
#
# ...

# %%
casas_p_bairro = df_n_repete.groupby("neighbourhood")
casas_p_bairro.groups.keys()
# Out:
# dict_keys(['$0.00', 'Abolição', 'Anchieta', 'Andaraí', 'Barra da Tijuca', 'Barra de Guaratiba', 'Barros Filho', 'Benfica', 'Bento Ribeiro', 'Bonsucesso', 'Botafogo', 'Brás de Pina', 'Cachambi', 'Caju', 'Cascadura', 'Catete', 'Catumbi', 'Cavalcante', 'Centro', 'Cidade Nova', 'Coelho Neto', 'Colégio', 'Complexo da Maré', 'Complexo de Alemão', 'Copacabana', 'Cordovil', 'Cosme Velho', 'Del Castilho', 'Deodoro', 'Encantado', 'Engenheiro Leal', 'Engenho Novo', 'Engenho da Rainha', 'Engenho de Dentro', 'Estacio', 'Flamengo', 'Gamboa', 'Glória', 'Grajaú', 'Grumari', 'Guadalupe', 'Gávea', 'Higienópolis', 'Honório Gurgel', 'Humaitá', 'Inhaúma', 'Ipanema', 'Irajá', 'Jacaré', 'Jardim América', 'Jardim Botânico', 'Joá', 'Lagoa', 'Lapa', 'Laranjeiras', 'Leblon', 'Leme', 'Lins de Vasconcelos', 'Madureira', 'Mangueira', 'Manguinhos', 'Maracanã', 'Marechal Hermes', 'Maria da Graça', 'Méier', 'Olaria', 'Oswaldo Cruz', 'Parada de Lucas', 'Parque Anchieta', 'Parque Colúmbia', 'Pavuna', 'Penha', 'Penha C
# ...

# %%
casa_copacabana = casas_p_bairro.get_group("Copacabana")
casa_botafogo = casas_p_bairro.get_group("Botafogo")
casa_alemao = casas_p_bairro.get_group("Complexo de Alemão")

# %%
copa_preco = casa_copacabana["price"].str.replace("$","")
copa_preco = copa_preco.str.replace(",","")
copa_preco = copa_preco.astype(float)

bot_preco = casa_botafogo["price"].str.replace("$","")
bot_preco = bot_preco.str.replace(",","")
bot_preco = bot_preco.astype(float)

alemao_preco = casa_alemao["price"].str.replace("$","")
alemao_preco = alemao_preco.str.replace(",","")
alemao_preco = alemao_preco.astype(float)


media_copacabana = copa_preco.mean()
media_botafogo = bot_preco.mean()
media_alemao = alemao_preco.mean()

comparar = pd.DataFrame([media_copacabana , media_botafogo , media_alemao ])
comparar.plot.barh()

print(media_botafogo , media_copacabana , media_alemao)
# Out:
# 369.880764904387 494.73229556044856 678.6666666666666

# %%
casas_p_bairro2 = df.groupby("neighbourhood")



casa_copacabana = casas_p_bairro2.get_group("Copacabana")
casa_botafogo = casas_p_bairro2.get_group("Botafogo")
casa_alemao = casas_p_bairro2.get_group("Complexo de Alemão")

copa_preco = casa_copacabana["price"].str.replace("$","")
copa_preco = copa_preco.str.replace(",","")
copa_preco = copa_preco.astype(float)

bot_preco = casa_botafogo["price"].str.replace("$","")
bot_preco = bot_preco.str.replace(",","")
bot_preco = bot_preco.astype(float)

alemao_preco = casa_alemao["price"].str.replace("$","")
alemao_preco = alemao_preco.str.replace(",","")
alemao_preco = alemao_preco.astype(float)


media_copacabana = copa_preco.mean()
media_botafogo = bot_preco.mean()
media_alemao = alemao_preco.mean()

comparar = pd.DataFrame([media_copacabana , media_botafogo , media_alemao ])
comparar.plot.barh()

print(media_botafogo , media_copacabana , media_alemao)
# Out:
# 412.3041663385052 507.96832623921574 633.6935483870968

# %%
df_n_repete[df_n_repete["price"].isnull()]
# Out:
#           Unnamed: 0                            listing_url     scrape_id  \
# id
# 32590477     35710.0  https://www.airbnb.com/rooms/32590477  2.019031e+13
#
#          last_scraped                                             name  \
# id
# 32590477   2019-03-13  Na quadra da praia. Por aqui, só boas energias!
#
#                                                     summary  \
# id
# 32590477  Ap delicioso em rua pequena, sem saída, com vi...
#
#                                                       space  \
# id
# 32590477  Além do quarto, os hóspedes podem utilizar a s...
#
#                                                 description  \
# id
# 32590477  Ap delicioso em rua pequena, sem saída, com vi...
#
#          experiences_offered  \
# id
# 32590477                none
#
#                                       neighborhood_overview  ...  \
# id                                                           ...
# 32590477  Tudo! Metrô, supermercado Zona Sul e Pão de Aç...  ...
#
# ...

# %%
df_n_repete.columns
# Out:
# Index(['Unnamed: 0', 'listing_url', 'scrape_id', 'last_scraped', 'name',
#        'summary', 'space', 'description', 'experiences_offered',
#        'neighborhood_overview',
#        ...
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
#        'maximum_nights_avg_ntm', 'number_of_reviews_ltm',
#        'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms',
#        'calculated_host_listings_count_shared_rooms', 'id'],
#       dtype='object', length=108)

# %%
df_n_repete.drop(columns= [ 'has_availability', 'availability_30', 'availability_60',
       'availability_90', 'availability_365'], inplace= True)

# %%
df_n_repete.drop(columns= ['latitude', 'longitude', 'is_location_exact','weekly_price',
       'monthly_price', 'security_deposit', 'cleaning_fee','minimum_nights', 'maximum_nights', 'calendar_updated',
       'reviews_per_month', 'month','notes','summary','description', 'experiences_offered'], inplace= True)

# %%
df_n_repete.drop(columns= [ 'zipcode'], inplace= True)

# %%
df_n_repete.drop(columns= ['bed_type', 'amenities', 'square_feet', 'guests_included',
       'extra_people', 'calendar_last_scraped', 'number_of_reviews',
       'first_review', 'last_review', 'review_scores_rating',
       'review_scores_accuracy', 'review_scores_cleanliness',
       'review_scores_checkin', 'review_scores_communication',
       'review_scores_location', 'review_scores_value', 'requires_license',
       'license', 'jurisdiction_names', 'instant_bookable',
       'is_business_travel_ready', 'cancellation_policy',
       'require_guest_profile_picture', 'require_guest_phone_verification',
       'calculated_host_listings_count', 'minimum_minimum_nights',
       'maximum_minimum_nights', 'minimum_maximum_nights',
       'maximum_maximum_nights', 'minimum_nights_avg_ntm',
       'maximum_nights_avg_ntm', 'number_of_reviews_ltm',
       'calculated_host_listings_count_entire_homes',
       'calculated_host_listings_count_private_rooms',
       'calculated_host_listings_count_shared_rooms','room_type', 'accommodates',
       'neighbourhood_group_cleansed', 'city', 'state', 'market',
       'smart_location', 'country_code', 'country','space', 'neighborhood_overview', 'transit', 'access', 'interaction',
       'house_rules', 'thumbnail_url', 'medium_url', 'picture_url',
       'xl_picture_url', 'host_id', 'host_url', 'host_name', 'host_since',
       'host_location', 'host_about', 'host_response_time',
       'host_response_rate', 'host_acceptance_rate', 'host_is_superhost',
       'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood',
       'host_listings_count', 'host_total_listings_count',
       'host_verifications', 'host_has_profile_pic', 'host_identity_verified',
       'street', 'neighbourhood','Unnamed: 0', 'listing_url', 'scrape_id', 'last_scraped'], inplace= True)

# %%
df2 = df_n_repete

# %%
# Apagar a última linha
df2 = df2.drop('within an hour')

# %%
df2.head()
# Out:
#                                             name neighbourhood_cleansed  \
# id
# 17878          Very Nice 2Br - Copacabana - WiFi             Copacabana
# 21280           Renovated Modern Apt. Near Beach                Ipanema
# 24480           Nice and cozy near Ipanema Beach                Ipanema
# 25026  Beautiful Modern Decorated Studio in Copa             Copacabana
# 31560           NICE & COZY 1BDR - IPANEMA BEACH                Ipanema
#
#       property_type  bathrooms  bedrooms  beds    price     id
# id
# 17878   Condominium        1.0       2.0   2.0  $307.00  17878
# 21280     Apartment        2.0       2.0   4.0  $336.00  21280
# 24480     Apartment        1.0       1.0   1.0  $233.00  24480
# 25026     Apartment        1.0       1.0   2.0  $159.00  25026
# 31560     Apartment        1.0       1.0   2.0  $253.00  31560

# %%
grupo = df2.groupby('property_type')

# %%
grupo.first()
# Out:
#                                                                      name  \
# property_type
# Aparthotel                    Apart-Hotel moderno e espaçoso com serviços
# Apartment                                Renovated Modern Apt. Near Beach
# Barn                                        BAHAD EIGHT - ESCOLA DE LUTAS
# Bed and breakfast       GREAT VIEW -Guesthouse "CASA 48"- Santa Teresa...
# Boat                                   46 feet sailboat in Rio de Janeiro
# Boutique hotel                                Casa da Santa - Room Bulcao
# Bungalow                               New green Loft in Santa Teresa RIo
# Cabin                                     Espaço aconchegante e tranquilo
# Camper/RV                                             Luxurious Penthouse
# Campsite                                       Camping  São Conrado Canoa
# Casa particular              Apartamento Mobiliado 3 quartos independente
# ...

# %%
df2.isnull().sum()
# Out:
# name                       83
# neighbourhood_cleansed      1
# property_type               0
# bathrooms                 179
# bedrooms                  134
# beds                      497
# price                       1
# id                          0
# dtype: int64

# %%
Aparthotel = pd.DataFrame(grupo.get_group('Aparthotel'))
ap = pd.DataFrame(grupo.get_group('Apartment'))
celero = pd.DataFrame(grupo.get_group('Barn'))
cama_e_cafe = pd.DataFrame(grupo.get_group('Bed and breakfast'))
barco = pd.DataFrame(grupo.get_group('Boat'))
Boutique = pd.DataFrame(grupo.get_group('Boutique hotel'))
bungaloow = pd.DataFrame(grupo.get_group('Bungalow'))
Cabin = pd.DataFrame(grupo.get_group('Cabin'))
Camper = pd.DataFrame(grupo.get_group('Camper/RV'))
Camsite = pd.DataFrame(grupo.get_group('Campsite'))
Casa_particular= pd.DataFrame(grupo.get_group('Casa particular'))
Casa_p_Cuba= pd.DataFrame(grupo.get_group('Casa particular (Cuba)'))
Castelo = pd.DataFrame(grupo.get_group('Castle'))
Chalet= pd.DataFrame(grupo.get_group('Chalet'))
Condominio = pd.DataFrame(grupo.get_group('Condominium'))
Cottage = pd.DataFrame(grupo.get_group('Cottage'))
Domo = pd.DataFrame(grupo.get_group('Dome house'))
Dorm = pd.DataFrame(grupo.get_group('Dorm'))
Earth= pd.DataFrame(grupo.get_group('Earth house'))
Farm_house= pd.DataFrame(grupo.get_group('Farm stay'))
Guest_suit= pd.DataFrame(grupo.get_group('Guest suite'))
Guest_House= pd.DataFrame(grupo.get_group('Guesthouse'))
Hostel = pd.DataFrame(grupo.get_group('Hostel'))
Hotel = pd.DataFrame(grupo.get_group('Hotel'))
Casa = pd.DataFrame(grupo.get_group('House'))
Houseboat = pd.DataFrame(grupo.get_group('Houseboat'))
Hut = pd.DataFrame(grupo.get_group('Hut'))
Igloo = pd.DataFrame(grupo.get_group('Igloo'))
Island = pd.DataFrame(grupo.get_group('Island'))
loft = pd.DataFrame(grupo.get_group('Loft'))
Nature= pd.DataFrame(grupo.get_group('Nature lodge'))
other = pd.DataFrame(grupo.get_group('Other'))
Parking_Space= pd.DataFrame(grupo.get_group('Parking Space'))
pensao_sk= pd.DataFrame(grupo.get_group('Pension (South Korea)'))
plane = pd.DataFrame(grupo.get_group('Plane'))
Resort = pd.DataFrame(grupo.get_group('Resort'))
Serviced_apartment= pd.DataFrame(grupo.get_group('Serviced apartment'))
Tent = pd.DataFrame(grupo.get_group('Tent'))
Tiny_house = pd.DataFrame(grupo.get_group('Tiny house'))
Tipi= pd.DataFrame(grupo.get_group('Tipi'))
Townhouse = pd.DataFrame(grupo.get_group('Townhouse'))
train = pd.DataFrame(grupo.get_group('Train'))
tree_HOUSE= pd.DataFrame(grupo.get_group('Treehouse'))
vacation_home = pd.DataFrame(grupo.get_group('Vacation home'))
villa = pd.DataFrame(grupo.get_group('Villa'))
yurt = pd.DataFrame(grupo.get_group('Yurt'))

# %%
list_tipos = [Aparthotel,ap,celero,cama_e_cafe,barco,Boutique,bungaloow,Cabin,Camper,Camsite,Casa_particular,Casa_p_Cuba,Castelo,
Chalet,Condominio,Cottage,Domo,Dorm,Earth,Farm_house,Guest_suit,Guest_House,Hostel,Hotel,Casa,Houseboat,Hut,Igloo,Island,
loft,Nature,other,Parking_Space,pensao_sk,plane,Resort,Serviced_apartment,Tent,Tiny_house,Tipi,Townhouse,train,tree_HOUSE,vacation_home,villa,yurt,]

# %%
lista_n_tipos = ['Aparthotel','ap','celero','cama_e_cafe','barco','Boutique','bungaloow','Cabin','Camper','Camsite','Casa_particular','Casa_p_Cuba','Castelo',
'Chalet','Condominio','Cottage','Domo','Dorm','Earth','Farm_house','Guest_suit','Guest_House','Hostel','Hotel','Casa','Houseboat','Hut','Igloo','Island',
'loft','Nature','other','Parking_Space','pensao_sk','plane','Resort','Serviced_apartment','Tent','Tiny_house','Tipi','Townhouse','train','tree_HOUSE','vacation_home','villa','yurt']

# %%
for i in range(len(list_tipos)):
    print("="*60)
    print(lista_n_tipos[i])
    print(list_tipos[i].isnull().sum())
# Out:
# ...
# Aparthotel
# name                      0
# neighbourhood_cleansed    0
# property_type             0
# bathrooms                 0
# bedrooms                  0
# beds                      0
# price                     0
# id                        0
# dtype: int64
# ...
# ap
# name                       74
# neighbourhood_cleansed      1
# property_type               0
# bathrooms                 131
# bedrooms                  103
# beds                      335
# price                       1
# id                          0
# dtype: int64
# ...
# celero
# name                      0
# neighbourhood_cleansed    0
# property_type             0
# bathrooms                 0
# bedrooms                  0
# beds                      0
# price                     0
# id                        0
# dtype: int64
# ...
# cama_e_cafe
# name                       0
# neighbourhood_cleansed     0
# property_type              0
# bathrooms                 11
# bedrooms                   0
# ...

# %%
banheiros_ap = ap[ap["bathrooms"].notnull()]

# %%
round(banheiros_ap["bathrooms"].mean())
# Out:
# 2

# %%
ap["bathrooms"].fillna(2 , inplace= True)

# %%
quartos_ap = ap[ap["bedrooms"].notnull()]
numero_quartos = round(quartos_ap["bedrooms"].mean())
ap["bedrooms"].fillna( numero_quartos , inplace= True)

# %%
camas_ap = ap[ap["beds"].notnull()]
numero_camas = round(camas_ap["beds"].mean())
ap["beds"].fillna( numero_camas , inplace= True)
print(numero_camas)
# Out:
# 2

# %%
banheiro_cama_e_cafe = cama_e_cafe[cama_e_cafe["bathrooms"].notnull()]
numero_banheiro = round(banheiro_cama_e_cafe["bathrooms"].mean())
cama_e_cafe["bathrooms"].fillna( numero_banheiro , inplace= True)
print(numero_banheiro)
# Out:
# 2

# %%
camas_cama_e_cafe = cama_e_cafe[cama_e_cafe["beds"].notnull()]
numero_camas = round(camas_cama_e_cafe["beds"].mean())
cama_e_cafe["beds"].fillna( numero_camas , inplace= True)
print(numero_camas)
# Out:
# 4

# %%
quartos_Casa_p_Cuba = Casa_p_Cuba[Casa_p_Cuba["bedrooms"].notnull()]
numero_quartos = round(quartos_Casa_p_Cuba["bedrooms"].mean())
Casa_p_Cuba["bedrooms"].fillna( numero_quartos , inplace= True)

# %%
camas_Casa_p_Cuba = Casa_p_Cuba[Casa_p_Cuba["beds"].notnull()]
numero_camas = round(camas_Casa_p_Cuba["beds"].mean())
Casa_p_Cuba["beds"].fillna( numero_camas , inplace= True)
print(numero_camas)
# Out:
# 2

# %%
camas_Condominio = Condominio[Condominio["beds"].notnull()]
numero_camas = round(camas_Condominio["beds"].mean())
Condominio["beds"].fillna( numero_camas , inplace= True)
print(numero_camas)
camas_Condominio = Condominio[Condominio["bedrooms"].notnull()]
numero_quarto = round(camas_Condominio["bedrooms"].mean())
Condominio["bedrooms"].fillna( numero_quarto , inplace= True)
print(numero_quarto)
camas_Condominio = Condominio[Condominio["bathrooms"].notnull()]
numero_banheiro = round(camas_Condominio["bathrooms"].mean())
Condominio["bathrooms"].fillna( numero_banheiro , inplace= True)
print(numero_banheiro)
# Out:
# 3
# 2
# 2

# %%
camas_Earth = Earth[Earth["beds"].notnull()]
numero_camas = round(camas_Earth["beds"].mean())
Earth["beds"].fillna( numero_camas , inplace= True)
print(numero_camas)
# Out:
# 2

# %%
camas_Guest_suit = Guest_suit[Guest_suit["beds"].notnull()]
numero_camas = round(camas_Guest_suit["beds"].mean())
Guest_suit["beds"].fillna( numero_camas , inplace= True)
print(numero_camas)
# Out:
# 2

# %%
camas_Guest_House = Guest_House[Guest_House["beds"].notnull()]
numero_camas = round(camas_Guest_House["beds"].mean())
Guest_House["beds"].fillna( numero_camas , inplace= True)
print(numero_camas)
camas_Guest_House = Guest_House[Guest_House["bedrooms"].notnull()]
numero_camas = round(camas_Guest_House["bedrooms"].mean())
Guest_House["bedrooms"].fillna( numero_camas , inplace= True)
print(numero_camas)
# Out:
# 3
# 1

# %%
camas_Hostel = Hostel[Hostel["beds"].notnull()]
numero_camas = round(camas_Hostel["beds"].mean())
Hostel["beds"].fillna( numero_camas , inplace= True)
print(numero_camas)
camas_Hostel = Hostel[Hostel["bedrooms"].notnull()]
numero_quarto = round(camas_Hostel["bedrooms"].mean())
Hostel["bedrooms"].fillna( numero_quarto , inplace= True)
print(numero_quarto)
camas_Hostel = Hostel[Hostel["bathrooms"].notnull()]
numero_banheiro = round(camas_Hostel["bathrooms"].mean())
Hostel["bathrooms"].fillna( numero_banheiro , inplace= True)
print(numero_banheiro)
# Out:
# 4
# 1
# 2

# %%
camas_Casa = Casa[Casa["beds"].notnull()]
numero_camas = round(camas_Casa["beds"].mean())
Casa["beds"].fillna( numero_camas , inplace= True)
print(numero_camas)
camas_Casa = Casa[Casa["bedrooms"].notnull()]
numero_quarto = round(camas_Casa["bedrooms"].mean())
Casa["bedrooms"].fillna( numero_quarto , inplace= True)
print(numero_quarto)
camas_Casa = Casa[Casa["bathrooms"].notnull()]
numero_banheiro = round(camas_Casa["bathrooms"].mean())
Casa["bathrooms"].fillna( numero_banheiro , inplace= True)
print(numero_banheiro)
# Out:
# 3
# 2
# 2

# %%
camas_loft = loft[loft["beds"].notnull()]
numero_camas = round(camas_loft["beds"].mean())
loft["beds"].fillna( numero_camas , inplace= True)
print(numero_camas)
camas_loft = loft[loft["bedrooms"].notnull()]
numero_quarto = round(camas_loft["bedrooms"].mean())
loft["bedrooms"].fillna( numero_quarto , inplace= True)
print(numero_quarto)
camas_loft = loft[loft["bathrooms"].notnull()]
numero_banheiro = round(camas_loft["bathrooms"].mean())
loft["bathrooms"].fillna( numero_banheiro , inplace= True)
print(numero_banheiro)
# Out:
# 2
# 1
# 1

# %%
camas_other = other[other["beds"].notnull()]
numero_camas = round(camas_other["beds"].mean())
other["beds"].fillna( numero_camas , inplace= True)
print(numero_camas)
# Out:
# 3

# %%
camas_Serviced_apartment = Serviced_apartment[Serviced_apartment["beds"].notnull()]
numero_camas = round(camas_Serviced_apartment["beds"].mean())
Serviced_apartment["beds"].fillna( numero_camas , inplace= True)
print(numero_camas)
camas_Serviced_apartment = Serviced_apartment[Serviced_apartment["bedrooms"].notnull()]
numero_quarto = round(camas_Serviced_apartment["bedrooms"].mean())
Serviced_apartment["bedrooms"].fillna( numero_quarto , inplace= True)
print(numero_quarto)
camas_Serviced_apartment = Serviced_apartment[Serviced_apartment["bathrooms"].notnull()]
numero_banheiro = round(camas_Serviced_apartment["bathrooms"].mean())
Serviced_apartment["bathrooms"].fillna( numero_banheiro , inplace= True)
print(numero_banheiro)
# Out:
# 2
# 1
# 1

# %%
camas_Tiny_house = Tiny_house[Tiny_house["beds"].notnull()]
numero_camas = round(camas_Tiny_house["beds"].mean())
Tiny_house["beds"].fillna( numero_camas , inplace= True)
print(numero_camas)
camas_Tiny_house = Tiny_house[Tiny_house["bedrooms"].notnull()]
numero_quarto = round(camas_Tiny_house["bedrooms"].mean())
Tiny_house["bedrooms"].fillna( numero_quarto , inplace= True)
print(numero_quarto)
camas_Tiny_house = Tiny_house[Tiny_house["bathrooms"].notnull()]
numero_banheiro = round(camas_Tiny_house["bathrooms"].mean())
Tiny_house["bathrooms"].fillna( numero_banheiro , inplace= True)
print(numero_banheiro)
# Out:
# 2
# 1
# 1

# %%
camas_Townhouse = Townhouse[Townhouse["beds"].notnull()]
numero_camas = round(camas_Townhouse["beds"].mean())
Townhouse["beds"].fillna( numero_camas , inplace= True)
print(numero_camas)
camas_Townhouse = Townhouse[Townhouse["bedrooms"].notnull()]
numero_quarto = round(camas_Townhouse["bedrooms"].mean())
Townhouse["bedrooms"].fillna( numero_quarto , inplace= True)
print(numero_quarto)
camas_Townhouse = Townhouse[Townhouse["bathrooms"].notnull()]
numero_banheiro = round(camas_Townhouse["bathrooms"].mean())
Townhouse["bathrooms"].fillna( numero_banheiro , inplace= True)
print(numero_banheiro)
# Out:
# 2
# 1
# 2

# %%
camas_villa = villa[villa["beds"].notnull()]
numero_camas = round(camas_villa["beds"].mean())
villa["beds"].fillna( numero_camas , inplace= True)
print(numero_camas)
# Out:
# 4

# %%
ap["price"].fillna(0, inplace= True)

# %%
for i in range(len(list_tipos)):
    print("="*60)
    print(lista_n_tipos[i])
    print(list_tipos[i].isnull().sum())
# Out:
# ...
# Aparthotel
# name                      0
# neighbourhood_cleansed    0
# property_type             0
# bathrooms                 0
# bedrooms                  0
# beds                      0
# price                     0
# id                        0
# dtype: int64
# ...
# ap
# name                      74
# neighbourhood_cleansed     1
# property_type              0
# bathrooms                  0
# bedrooms                   0
# beds                       0
# price                      0
# id                         0
# dtype: int64
# ...
# celero
# name                      0
# neighbourhood_cleansed    0
# property_type             0
# bathrooms                 0
# bedrooms                  0
# beds                      0
# price                     0
# id                        0
# dtype: int64
# ...
# cama_e_cafe
# name                      0
# neighbourhood_cleansed    0
# property_type             0
# bathrooms                 0
# bedrooms                  0
# beds                      0
# ...

# %%
combined_df = pd.concat(list_tipos, ignore_index=True)

# %%
import pandas as pd
from matplotlib import pyplot as plt
import sklearn.model_selection as ms
import sklearn.linear_model as lm
import numpy as np

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73902 entries, 0 to 73901
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   name                    73819 non-null  object
#  1   neighbourhood_cleansed  73901 non-null  object
#  2   property_type           73902 non-null  object
#  3   bathrooms               73902 non-null  float64
#  4   bedrooms                73902 non-null  float64
#  5   beds                    73902 non-null  float64
#  6   price                   73902 non-null  object
#  7   id                      73902 non-null  object
# dtypes: float64(3), object(5)
# memory usage: 4.5+ MB

# %%
data = combined_df
data["price"] = data["price"].str.replace("$","")
data["price"] = data["price"].str.replace(",","")
data["price"] = data["price"].astype(float)

# %%
data["price"].fillna(0 , inplace= True)

# %%
data.drop(columns=['name'] , inplace= True)

# %%
data.columns
# Out:
# Index(['neighbourhood_cleansed', 'property_type', 'bathrooms', 'bedrooms',
#        'beds', 'price', 'id'],
#       dtype='object')

# %%
X = data.iloc[:, :-2]
y = data["price"].values

# %%
X_dummies = pd.get_dummies(X)
X_dummies
# Out:
#        bathrooms  bedrooms  beds  neighbourhood_cleansed_Abolição  \
# 0            2.0       1.0   1.0                            False
# 1            1.0       1.0   2.0                            False
# 2            1.0       1.0   1.0                            False
# 3            2.0       2.0   3.0                            False
# 4            1.0       1.0   1.0                            False
# ...          ...       ...   ...                              ...
# 73897        2.0       1.0   6.0                            False
# 73898        2.0       1.0   6.0                            False
# 73899        2.0       1.0   6.0                            False
# 73900        2.0       1.0   6.0                            False
# 73901        1.0       2.0   2.0                            False
#
#        neighbourhood_cleansed_Alto da Boa Vista  \
# 0                                         False
# 1                                         False
# ...

# %%
X_train, X_test, y_train, y_test = ms.train_test_split(X_dummies, y, test_size = 1/5, random_state = 0)

# %%
regressao = lm.LinearRegression()
regressao.fit(X_train , y_train)
y_pred = regressao.predict(X_test)
np.set_printoptions(precision=2)

# %%
result = np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1)

# %%
def undummify(df, prefix_sep="_"):
    cols2collapse = {
        item.split(prefix_sep)[0]: (prefix_sep in item) for item in df.columns
    }
    series_list = []
    for col, needs_to_collapse in cols2collapse.items():
        if needs_to_collapse:
            undummified = (
                df.filter(like=col)
                .idxmax(axis=1)
                .apply(lambda x: x.split(prefix_sep, maxsplit=1)[1])
                .rename(col)
            )
            series_list.append(undummified)
        else:
            series_list.append(df[col])
    undummified_df = pd.concat(series_list, axis=1)
    return undummified_df

X_reverse = undummify(X_test)

X_reverse = X_reverse.reset_index(drop=True)

# %%
y_compare = pd.DataFrame(result)
y_compare = y_compare.rename(index=str, columns={0:'y_pred', 1:'y_test'})
y_compare = y_compare.reset_index(drop=True)

# %%
resultado_final = pd.concat([y_compare, X_reverse], axis=1)

# %%
resultado_final
# Out:
#             y_pred  y_test  bathrooms  bedrooms  beds  \
# 0       787.425781   332.0        2.0       2.0   3.0
# 1       624.417969   152.0        2.0       1.0   1.0
# 2       396.621094    62.0        1.5       1.0   1.0
# 3       396.152344   180.0        1.0       2.0   2.0
# 4       391.156250  1500.0        1.0       1.0   2.0
# ...            ...     ...        ...       ...   ...
# 14776   116.390625   127.0        1.0       1.0   1.0
# 14777  2384.187500   998.0        6.0       4.0   5.0
# 14778   720.082031   699.0        2.0       2.0   5.0
# 14779   275.703125    38.0        1.0       2.0   4.0
# 14780   371.417969   252.0        1.0       1.0   1.0
#
#                            neighbourhood                 property
# 0                        cleansed_Leblon  type_Serviced apartment
# 1                    cleansed_Copacabana           type_Apartment
# 2                        cleansed_Glória               type_House
# ...
