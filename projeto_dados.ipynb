# %%
import pandas as pd
url = "C:\\Users\\user\\Documents\\FACULDADE\\total_data.csv"
tabela = pd.read_csv(url)
tabela_junho2019 = pd.read_csv("C:\\Users\\user\\Documents\\FACULDADE\\junho2019.csv")

# %%
tabela.head(9)
# Out:
#    Unnamed: 0     id                         listing_url     scrape_id  \
# 0         0.0  17878  https://www.airbnb.com/rooms/17878  2.018082e+13
# 1         1.0  24480  https://www.airbnb.com/rooms/24480  2.018082e+13
# 2         2.0  25026  https://www.airbnb.com/rooms/25026  2.018082e+13
# 3         3.0  31560  https://www.airbnb.com/rooms/31560  2.018082e+13
# 4         4.0  35636  https://www.airbnb.com/rooms/35636  2.018082e+13
# 5         5.0  35764  https://www.airbnb.com/rooms/35764  2.018082e+13
# 6         6.0  35893  https://www.airbnb.com/rooms/35893  2.018082e+13
# 7         7.0  46937  https://www.airbnb.com/rooms/46937  2.018082e+13
# 8         8.0  48305  https://www.airbnb.com/rooms/48305  2.018082e+13
#
#   last_scraped                                               name  \
# 0   2018-08-16                  Very Nice 2Br - Copacabana - WiFi
# 1   2018-08-16                   Nice and cozy near Ipanema Beach
# ...

# %%
tabela.info()

# %%
tabela["summary"].str.strip()

# %%
sumario_nulo = tabela[tabela["city"].isnull()]
sumario_nulo

# %%
new_data = tabela
new = pd.DataFrame(new_data)
new.to_csv("total_dataV2", index= False)

# %%
filtro = tabela["neighbourhood"] == "Ipanema"
tabela_ipanema = tabela[filtro]
tabela_ipanema["price"]

# %%
valores = tabela_ipanema["price"].str.replace("$" , "0")
valores2 = valores.str.replace(",","")
valores2 = valores2.str.replace(".","")
valores2 = valores2.astype(int)
v = valores2/100
v.mean()

# %%
filtro = tabela["neighbourhood"] == "Botafogo"
tabela_botfire = tabela[filtro]
valoresbot = tabela_botfire["price"].str.replace("$" , "0")
valoresbot2 = valoresbot.str.replace(",","")
valoresbot2 = valoresbot2.str.replace(".","")
valoresbot2 = valoresbot2.astype(int)
v = valoresbot2/100
v.mean()

# %%
tabela_abril2020 = pd.read_csv("C:\\Users\\user\\Downloads\\archive (8)\\abril2020.csv")
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_15740\1133020457.py:1: DtypeWarning: Columns (61,62,94) have mixed types. Specify dtype option on import or set low_memory=False.
#   tabela_abril2020 = pd.read_csv("C:\\Users\\user\\Downloads\\archive (8)\\abril2020.csv")

# %%
tabela_julho2018 = pd.read_csv("C:\\Users\\user\\Downloads\\archive (8)\\julho2018.csv")
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_15740\2938787638.py:1: DtypeWarning: Columns (87) have mixed types. Specify dtype option on import or set low_memory=False.
#   tabela_julho2018 = pd.read_csv("C:\\Users\\user\\Downloads\\archive (8)\\julho2018.csv")

# %%
tabela_agosto2019 = pd.read_csv("C:\\Users\\user\\Downloads\\archive (8)\\agosto2019.csv")
tabela_maio2018 = pd.read_csv("C:\\Users\\user\\Downloads\\archive (8)\\maio2018.csv")
tabela_dezembro2019 = pd.read_csv("C:\\Users\\user\\Downloads\\archive (8)\\dezembro2019.csv")
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_15740\598689988.py:1: DtypeWarning: Columns (61,62,94) have mixed types. Specify dtype option on import or set low_memory=False.
#   tabela_agosto2019 = pd.read_csv("C:\\Users\\user\\Downloads\\archive (8)\\agosto2019.csv")
# C:\Users\user\AppData\Local\Temp\ipykernel_15740\598689988.py:2: DtypeWarning: Columns (87) have mixed types. Specify dtype option on import or set low_memory=False.
#   tabela_maio2018 = pd.read_csv("C:\\Users\\user\\Downloads\\archive (8)\\maio2018.csv")
# C:\Users\user\AppData\Local\Temp\ipykernel_15740\598689988.py:3: DtypeWarning: Columns (61,62,94) have mixed types. Specify dtype option on import or set low_memory=False.
#   tabela_dezembro2019 = pd.read_csv("C:\\Users\\user\\Downloads\\archive (8)\\dezembro2019.csv")

# %%
tabela_setembro2019 = pd.read_csv("C:\\Users\\user\\Downloads\\archive (8)\\setembro2019.csv")
tabela_abril2018 = pd.read_csv("C:\\Users\\user\\Downloads\\archive (8)\\abril2018.csv")
tabela_abril2019 = pd.read_csv("C:\\Users\\user\\Downloads\\archive (8)\\abril2019.csv")
tabela_agosto2018 = pd.read_csv("C:\\Users\\user\\Downloads\\archive (8)\\agosto2018.csv")
tabela_dezembro2018 = pd.read_csv("C:\\Users\\user\\Downloads\\archive (8)\\dezembro2018.csv")
tabela_fevereiro2019 = pd.read_csv("C:\\Users\\user\\Downloads\\archive (8)\\fevereiro2019.csv")
tabela_fevereiro2020 = pd.read_csv("C:\\Users\\user\\Downloads\\archive (8)\\fevereiro2020.csv")
tabela_janeiro2019 = pd.read_csv("C:\\Users\\user\\Downloads\\archive (8)\\janeiro2019.csv")
tabela_janeiro2020 = pd.read_csv("C:\\Users\\user\\Downloads\\archive (8)\\janeiro2020.csv")
tabela_julho2019 = pd.read_csv("C:\\Users\\user\\Downloads\\archive (8)\\julho2019.csv")
tabela_maio2019 = pd.read_csv("C:\\Users\\user\\Downloads\\archive (8)\\maio2019.csv")
tabela_maio2020 = pd.read_csv("C:\\Users\\user\\Downloads\\archive (8)\\abril2020.csv")
tabela_maro2019 = pd.read_csv("C:\\Users\\user\\Downloads\\archive (8)\\maro2019.csv")
tabela_maro2020 = pd.read_csv("C:\\Users\\user\\Downloads\\archive (8)\\maro2020.csv")
tabela_novembro2018 = pd.read_csv("C:\\Users\\user\\Downloads\\archive (8)\\novembro2018.csv")
tabela_novembro2019 = pd.read_csv("C:\\Users\\user\\Downloads\\archive (8)\\novembro2019.csv")
tabela_outubro2018 = pd.read_csv("C:\\Users\\user\\Downloads\\archive (8)\\outubro2018.csv")
tabela_outubro2019 = pd.read_csv("C:\\Users\\user\\Downloads\\archive (8)\\outubro2019.csv")
tabela_setembro2018 = pd.read_csv("C:\\Users\\user\\Downloads\\archive (8)\\setembro2018.csv")
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_15740\1303854981.py:1: DtypeWarning: Columns (61,62,94) have mixed types. Specify dtype option on import or set low_memory=False.
#   tabela_setembro2019 = pd.read_csv("C:\\Users\\user\\Downloads\\archive (8)\\setembro2019.csv")
# C:\Users\user\AppData\Local\Temp\ipykernel_15740\1303854981.py:2: DtypeWarning: Columns (62,87) have mixed types. Specify dtype option on import or set low_memory=False.
#   tabela_abril2018 = pd.read_csv("C:\\Users\\user\\Downloads\\archive (8)\\abril2018.csv")
# C:\Users\user\AppData\Local\Temp\ipykernel_15740\1303854981.py:3: DtypeWarning: Columns (61,62,94) have mixed types. Specify dtype option on import or set low_memory=False.
#   tabela_abril2019 = pd.read_csv("C:\\Users\\user\\Downloads\\archive (8)\\abril2019.csv")
# C:\Users\user\AppData\Local\Temp\ipykernel_15740\1303854981.py:4: DtypeWarning: Columns (87) have mixed types. Specify dtype option on import or set low_memory=False.
# ...

# %%
tabela[tabela["price"].isnull()]
# Out:
#         Unnamed: 0        id                            listing_url  \
# 290069     35710.0  32590477  https://www.airbnb.com/rooms/32590477
#
#            scrape_id last_scraped  \
# 290069  2.019031e+13   2019-03-13
#
#                                                    name  \
# 290069  Na quadra da praia. Por aqui, só boas energias!
#
#                                                   summary  \
# 290069  Ap delicioso em rua pequena, sem saída, com vi...
#
#                                                     space  \
# 290069  Além do quarto, os hóspedes podem utilizar a s...
#
#                                               description experiences_offered  \
# 290069  Ap delicioso em rua pequena, sem saída, com vi...                none
#
#         ... maximum_minimum_nights minimum_maximum_nights  \
# 290069  ...                    NaN                    NaN
#
#        maximum_maximum_nights minimum_nights_avg_ntm maximum_nights_avg_ntm  \
# ...

# %%
tabela_setembro2019.loc[tabela_setembro2019["id"] == 32590477	 ]
# Out:
# Empty DataFrame
# ...

# %%
tabela[tabela["property_type"].isnull()]
# Out:
#         Unnamed: 0        id                            listing_url  \
# 290069     35710.0  32590477  https://www.airbnb.com/rooms/32590477
#
#            scrape_id last_scraped  \
# 290069  2.019031e+13   2019-03-13
#
#                                                    name  \
# 290069  Na quadra da praia. Por aqui, só boas energias!
#
#                                                   summary  \
# 290069  Ap delicioso em rua pequena, sem saída, com vi...
#
#                                                     space  \
# 290069  Além do quarto, os hóspedes podem utilizar a s...
#
#                                               description experiences_offered  \
# 290069  Ap delicioso em rua pequena, sem saída, com vi...                none
#
#         ... maximum_minimum_nights minimum_maximum_nights  \
# 290069  ...                    NaN                    NaN
#
#        maximum_maximum_nights minimum_nights_avg_ntm maximum_nights_avg_ntm  \
# ...

# %%
ta
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0  17878  https://www.airbnb.com/rooms/17878  20190619182032   2019-06-20
# 1  25026  https://www.airbnb.com/rooms/25026  20190619182032   2019-06-20
# 2  31560  https://www.airbnb.com/rooms/31560  20190619182032   2019-06-20
# 3  35636  https://www.airbnb.com/rooms/35636  20190619182032   2019-06-20
# 4  35764  https://www.airbnb.com/rooms/35764  20190619182032   2019-06-20
#
#                                         name  \
# 0          Very Nice 2Br - Copacabana - WiFi
# 1  Beautiful Modern Decorated Studio in Copa
# 2           NICE & COZY 1BDR - IPANEMA BEACH
# 3           Cosy flat close to Ipanema beach
# 4              COPACABANA SEA BREEZE  -  RIO
#
#                                              summary  \
# 0  Please note that special rates apply for Carni...
# 1  Our apartment is a little gem, everyone loves ...
# 2  This nice and clean 1 bedroom apartment is loc...
# ...
